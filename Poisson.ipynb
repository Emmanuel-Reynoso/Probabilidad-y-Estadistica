# %% [markdown]
# # Visualización de la tabla de Poisson

# %%
import sys
sys.path.insert(0,'./modules')
from poisson import *

# %% [markdown]
# ---
# ## Función de distribución

# %%
show()

# %% [markdown]
# ---
# ## Función de distribución acumulada

# %%
show_cummulative()
