# %%
import sys
sys.path.insert(0,'./modules')
from continuas import *

# %% [markdown]
# # Visualizacion de Distribuciones Continuas

# %% [markdown]
# ---
# ## <center> Distribucion Exponencial</center>

# %%
exp_demo()

# %% [markdown]
# ---
# ## <center>Distribucion Chi<sup>2</sup></center>

# %%
chi_demo()

# %% [markdown]
# ---
# ## <center>Distribucion Gamma</center>

# %%
gamma_demo1()
